# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(3,2),facecolor="green")
plt.plot()
plt.show()

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
fig=plt.figure()
plt.subplot(221)
plt.subplot(222)
plt.subplot(223)
plt.rcParams["font.sans-serif"]="SimHei"
plt.show()

# %%
plt.rcParams["font.family"]="SimHei"
fig=plt.figure(facecolor="lightgrey")
plt.subplot(2,2,1)
plt.title('11111111')
plt.subplot(2,2,2)
plt.title('222222222',loc="left",color="b")
plt.subplot(2,2,3)
myfontdict={
    "fontsize":12,
    "color":"g",
    "rotation":30
}
plt.title('333333333',fontdict=myfontdict)
plt.subplot(2,2,4)
plt.title('44444444',color="white",backgroundcolor="black")
plt.suptitle("000",fontsize=20,color="red",backgroundcolor="yellow")
plt.tight_layout(rect=[0,0,1,0.9])
plt.show()

# %%
plt.rcParams['font.sans-serif']="SimHei"
plt.rcParams['axes.unicode_minus']=False

n=1024
x=np.random.normal(0,1,n)
y=np.random.normal(0,1,n)

plt.scatter(x,y,color="blue",marker='*')

plt.title("标准正态分布",fontsize=20)
plt.text=(2.5,2.5,"均值:0\n标准差:1")

plt.xlim(-4,4)
plt.ylim(-4,4)

plt.xlabel('横坐标x',fontsize=14)
plt.ylabel('纵坐标y',fontsize=14)

plt.show()

# %%
n=1024

x1=np.random.normal(0,1,n)
y1=np.random.normal(0,1,n)

x2=np.random.uniform(-4,4,(1,n))
y2=np.random.uniform(-4,4,(1,n))

plt.scatter(x1,y1,color="blue",marker='*',label="正态分布")
plt.scatter(x2,y2,color="yellow",marker='o',label="均匀分布")
plt.legend()
plt.title("标准正态分布",fontsize=20)

plt.xlim(-4,4)
plt.ylim(-4,4)
# Out:
# (-4.0, 4.0)

# %%
plt.rcParams['font.sans-serif']='SimHei'

n=24
y1=np.random.randint(27,37,n)
y2=np.random.randint(40,60,n)

plt.plot(y1,label='温度')
plt.plot(y2,label='湿度')

plt.xlim(0,23)
plt.ylim(20,70)
plt.xlabel('小时',fontsize=12)
plt.ylabel('测量值',fontsize=12)

plt.title('24小时温度湿度统计',fontsize=16)

plt.legend()
plt.show()

# %%
plt.rcParams['font.sans-serif']='SimHei'
plt.rcParams["axes.unicode_minus"]=False

y1=[32,25,16,30,24,45,40,33,28,17,23,20]
y2=[-23,-35,-26,-35,-45,-43,-35,-32,-23,-17,-22,-28]

plt.bar(range(len(y1)),y1,width=0.8,facecolor='green',edgecolor='white',label='统计量1')
plt.bar(range(len(y2)),y2,width=0.8,facecolor='red',edgecolor='white',label='统计量2')

plt.title("柱状图",fontsize=20)

plt.legend()
plt.show()
